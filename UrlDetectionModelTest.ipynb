# %%
#필요 모듈 import
import pandas as pd
import numpy as np

# %%
phising_site_url = pd.read_csv('./phishing_site_urls.csv')
phising_site_url = phising_site_url.dropna(axis=0)
phising_site_url
# Out:
#                                                       URL Label
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3       mail.printakid.com/www.online.americanexpress....   bad
# 4       thewhiskeydregs.com/wp-content/themes/widescre...   bad
# ...                                                   ...   ...
# 549341                                    23.227.196.215/   bad
# 549342                                 apple-checker.org/   bad
# 549343                                  apple-iclods.org/   bad
# 549344                                 apple-uptoday.org/   bad
# 549345                                  apple-search.info   bad
#
# [549346 rows x 2 columns]

# %% [markdown]
# # 새 섹션

# %%
good_site = phising_site_url[phising_site_url['Label'] == 'good']
bad_site = phising_site_url[phising_site_url['Label'] == 'bad']
print(good_site.Label.value_counts())
print(bad_site.Label.value_counts())
# Out:
# good    392924
# Name: Label, dtype: int64
# bad    156422
# Name: Label, dtype: int64

# %%
malicious_phish1 = pd.read_csv('.
/malicious_phish1.csv')
malicious_phish1
# Out:
#                                                       url        type
# 0                                        br-icloud.com.br    phishing
# 1                     mp3raid.com/music/krizz_kaliko.html      benign
# 2                         bopsecrets.org/rexroth/cr/1.htm      benign
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html    phishing
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    phishing
# 651188         www.gamespot.com/xbox360/action/deadspace/    phishing
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    phishing
# 651190          www.angelfire.com/goth/devilmaycrytonite/    phishing
#
# [651191 rows x 2 columns]

# %%
malicious_phish1 = malicious_phish1.dropna(axis = 0)
malicious_phish1.type.value_counts()
# Out:
# benign        428103
# defacement     96457
# phishing       94111
# malware        32520
# Name: type, dtype: int64

# %%
benign_site = malicious_phish1[malicious_phish1['type'] == 'benign']
nonbenign_site = malicious_phish1[malicious_phish1['type'] != 'benign']

benign_site['type'] = benign_site['type'].replace(['benign'], 'good')
nonbenign_site['type'] = nonbenign_site['type'].replace(['defacement','phishing','malware'], 'bad')

print(benign_site.type.value_counts())
print(nonbenign_site.type.value_counts())
# Out:
# good    428103
# Name: type, dtype: int64
# bad    223088
# Name: type, dtype: int64
# /var/folders/51/t3gqpmhd0ws50sv5mmn33j0m0000gn/T/ipykernel_3566/1789897956.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   benign_site['type'] = benign_site['type'].replace(['benign'], 'good')
# /var/folders/51/t3gqpmhd0ws50sv5mmn33j0m0000gn/T/ipykernel_3566/1789897956.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonbenign_site['type'] = nonbenign_site['type'].replace(['defacement','phishing','malware'], 'bad')

# %%
urlhaus = pd.read_csv('./urlhaus.csv')
urlhaus
# Out:
#            # id         dateadded  \
# 0       2605115   2023/04/11 0:49
# 1       2605114   2023/04/11 0:49
# 2       2605113   2023/04/11 0:48
# 3       2605112   2023/04/11 0:44
# 4       2605111   2023/04/11 0:39
# ...         ...               ...
# 103339   111418  2019/01/27 14:38
# 103340   111417  2019/01/27 14:38
# 103341   101043  2019/01/02 10:53
# 103342    91891  2018/12/08 23:09
# 103343    86646  2018/11/28 23:08
#
#                                                       url url_status  \
# 0                     http://117.217.235.149:55399/Mozi.m     online
# 1                     http://117.198.246.149:39794/bin.sh     online
# 2                         http://85.109.3.94:51470/bin.sh     online
# 3                           http://178.141.188.94:58650/i     online
# 4                            http://125.40.113.71:40588/i     online
# ...                                                   ...        ...
# 103339                    http://t.honker.info:8/madk.exe     online
# 103340                     http://t.honker.info:8/445.exe     online
# 103341  http://livetrack.in/EmployeeMasterImages/qace.jpg     online
# 103342                      http://63.245.122.93:29703/.i     online
# 103343                     http://123.194.235.37:49320/.i     online
#
#                 last_online            threat                     tags  \
# 0                      None  malware_download                 elf,Mozi
# 1                      None  malware_download     32-bit,elf,mips,Mozi
# 2                      None  malware_download     32-bit,elf,mips,Mozi
# 3                      None  malware_download     32-bit,elf,mips,Mozi
# 4                      None  malware_download     32-bit,elf,mips,Mozi
# ...                     ...               ...                      ...
# 103339  2023-04-01 21:XX:XX  malware_download  CoinMiner,EBDP,glupteba
# 103340  2023-03-31 20:XX:XX  malware_download           CoinMiner,EBDP
# 103341  2023-02-11 11:XX:XX  malware_download       arkei,Encoded,Task
# 103342                 None  malware_download               elf,hajime
# 103343                 None  malware_download               elf,hajime
#
#                                  urlhaus_link     reporter
# 0       https://urlhaus.abuse.ch/url/2605115/  lrz_urlhaus
# 1       https://urlhaus.abuse.ch/url/2605114/     geenensp
# 2       https://urlhaus.abuse.ch/url/2605113/     geenensp
# 3       https://urlhaus.abuse.ch/url/2605112/     geenensp
# 4       https://urlhaus.abuse.ch/url/2605111/     geenensp
# ...                                       ...          ...
# 103339   https://urlhaus.abuse.ch/url/111418/    anonymous
# 103340   https://urlhaus.abuse.ch/url/111417/    anonymous
# 103341   https://urlhaus.abuse.ch/url/101043/    anonymous
# 103342    https://urlhaus.abuse.ch/url/91891/  zbetcheckin
# 103343    https://urlhaus.abuse.ch/url/86646/  zbetcheckin
#
# [103344 rows x 9 columns]

# %%
urlhaus = urlhaus.dropna(axis = 0)
urlhaus.threat.value_counts()
# Out:
# malware_download    103344
# Name: threat, dtype: int64

# %%
good_site = good_site.rename(columns={'Label':'type'})
good_site = good_site.rename(columns={'URL':'url'})
bad_site = bad_site.rename(columns={'Label':'type'})
bad_site = bad_site.rename(columns={'URL':'url'})
bad_site
# Out:
#                                                       url type
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...  bad
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...  bad
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....  bad
# 3       mail.printakid.com/www.online.americanexpress....  bad
# 4       thewhiskeydregs.com/wp-content/themes/widescre...  bad
# ...                                                   ...  ...
# 549341                                    23.227.196.215/  bad
# 549342                                 apple-checker.org/  bad
# 549343                                  apple-iclods.org/  bad
# 549344                                 apple-uptoday.org/  bad
# 549345                                  apple-search.info  bad
#
# [156422 rows x 2 columns]

# %%
urlhaus['type'] = 'bad'
urlhaus = urlhaus.drop(['# id', 'dateadded', 'urlhaus_link' , 'url_status', 'last_online', 'threat', 'tags', 'reporter'], axis=1)
urlhaus
# Out:
#                                                       url type
# 0                     http://117.217.235.149:55399/Mozi.m  bad
# 1                     http://117.198.246.149:39794/bin.sh  bad
# 2                         http://85.109.3.94:51470/bin.sh  bad
# 3                           http://178.141.188.94:58650/i  bad
# 4                            http://125.40.113.71:40588/i  bad
# ...                                                   ...  ...
# 103339                    http://t.honker.info:8/madk.exe  bad
# 103340                     http://t.honker.info:8/445.exe  bad
# 103341  http://livetrack.in/EmployeeMasterImages/qace.jpg  bad
# 103342                      http://63.245.122.93:29703/.i  bad
# 103343                     http://123.194.235.37:49320/.i  bad
#
# [103344 rows x 2 columns]

# %%
#악성 url 데이터셋
test_data = pd.concat([bad_site, urlhaus])
test_data = pd.concat([test_data, nonbenign_site])
test_data
# Out:
#                                                       url type
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...  bad
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...  bad
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....  bad
# 3       mail.printakid.com/www.online.americanexpress....  bad
# 4       thewhiskeydregs.com/wp-content/themes/widescre...  bad
# ...                                                   ...  ...
# 651186            xbox360.ign.com/objects/850/850402.html  bad
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/  bad
# 651188         www.gamespot.com/xbox360/action/deadspace/  bad
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)  bad
# 651190          www.angelfire.com/goth/devilmaycrytonite/  bad
#
# [482854 rows x 2 columns]

# %%
#정상 url
data = pd.concat([benign_site,good_site])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 821027 entries, 1 to 483594
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   url     821027 non-null  object
#  1   type    821027 non-null  object
# dtypes: object(2)
# memory usage: 18.8+ MB

# %%
#데이터셋 모음
output = pd.concat([data, test_data])
output.to_csv('dataset.csv')

# %%
# !pip install python-whois
# Out:
# Collecting python-whois
#   Downloading python-whois-0.8.0.tar.gz (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 11.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python-whois, future
#   Building wheel for python-whois (setup.py) ... done
#   Created wheel for python-whois: filename=python_whois-0.8.0-py3-none-any.whl size=103247 sha256=eb8bb3785e5835901f2454a2b5610078dc5f22ccbdbd75993094e9bfc35267f5
#   Stored in directory: /Users/seongwon-ha/Library/Caches/pip/wheels/10/f1/87/145023b9a206e2e948be6480c61ef3fd3dbb81ef11b6977782
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492022 sha256=6a3cbbaa592b3a98006d5591ed81c1b39318532bdd1d464cfde2a365c0e22df8
#   Stored in directory: /Users/seongwon-ha/Library/Caches/pip/wheels/5e/a9/47/f118e66afd12240e4662752cc22cefae5d97275623aa8ef57d
# Successfully built python-whois future
# Installing collected packages: future, python-whois
# Successfully installed future-0.18.3 python-whois-0.8.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %% [markdown]
# 5번 특징 특수문자 과도한 사용

# %%
#url안 특수문자 개수 저장
dataset = output #데이터셋 따로 가져옴
specChar = [] #결과저장용 배열

for i, item in dataset.iterrows():
  cnt = 0
  cnt += item['url'].count('?')
  cnt += item['url'].count('!')
  cnt += item['url'].count('~')
  cnt += item['url'].count('@')
  cnt += item['url'].count('#')
  cnt += item['url'].count('$')
  cnt += item['url'].count('%')
  cnt += item['url'].count('^')
  cnt += item['url'].count('&')
  cnt += item['url'].count('*')
  cnt += item['url'].count('-')
  cnt += item['url'].count('=')
  cnt += item['url'].count('_')
  cnt += item['url'].count('+')
  cnt += item['url'].count(',')
  specChar.append(cnt)

dataset['specChar'] = specChar

# #배열 데이터프레임으로 타입변경
# specChar = pd.DataFrame(specChar, columns=['specChar'])

# #원활한 저장 위해 인덱스 초기화
# dataset = dataset.reset_index()
# specChar = specChar.reset_index()

# #데이터프레임 병합(index가 여러개 생기는 것 같은데 해결해야할수도)
# dataset = pd.concat([dataset, specChar], axis=1)

dataset
# Out:
#                                                       url  type  specChar
# 1                     mp3raid.com/music/krizz_kaliko.html  good         1
# 2                         bopsecrets.org/rexroth/cr/1.htm  good         0
# 5       http://buzzfil.net/m/show-art/ils-etaient-loin...  good        16
# 6           espn.go.com/nba/player/_/id/3457/brandon-rush  good         2
# 7          yourbittorrent.com/?q=anthony-hamilton-soulife  good         4
# ...                                                   ...   ...       ...
# 651186            xbox360.ign.com/objects/850/850402.html   bad         0
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/   bad         2
# 651188         www.gamespot.com/xbox360/action/deadspace/   bad         0
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)   bad         3
# 651190          www.angelfire.com/goth/devilmaycrytonite/   bad         0
#
# [1303881 rows x 3 columns]

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 20
# # row 생략 없이 출력
# pd.set_option('display.max_rows', None)
# # col 생략 없이 출력
# pd.set_option('display.max_columns', None)

# %%
dataset[dataset['type'] == 'bad']['specChar'].value_counts().head(27)
# Out:
# 0     267976
# 1      61092
# 2      32928
# 3      16109
# 4      12947
# 9      12742
# 5       9896
# 6       9561
# 7       8610
# 11      7713
# 10      6431
# 8       5773
# 12      4531
# 13      3880
# 16      2634
# 15      2604
# 14      2523
# 21      2208
# 18      2050
# 17      1917
# 19      1449
# 24      1338
# 20      1154
# 27      1116
# 22       827
# 23       544
# 25       330
# Name: specChar, dtype: int64

# %%
dataset[dataset['type'] == 'good']['specChar'].value_counts().head(27)
# Out:
# 0     265305
# 1     147890
# 2     119650
# 3      64757
# 4      51144
# 5      34392
# 6      29959
# 7      21407
# 8      17113
# 9      13483
# 10     10803
# 11      8483
# 12      7623
# 13      5411
# 14      4247
# 15      3262
# 16      2341
# 18      2166
# 17      1930
# 19      1141
# 20      1048
# 21       803
# 22       738
# 23       619
# 24       423
# 25       359
# 26       258
# Name: specChar, dtype: int64

# %% [markdown]
# 4번 특징 domain, path, patameter, TLD 길이가 길다

# %%
import pandas as pd
from urllib.parse import urlparse, parse_qs

df = pd.read_csv('./dataset.csv')

# %%
url_http = df[df['url'].str.contains('http')]

def extract_url_info(url):
    parsed_url = urlparse(url)
    
    # Set netloc format netloc 형식 구성
    if len(parsed_url.netloc) == 0:
        parsed_url = urlparse("//"+url)

    # Extract domain length domain 길이 추출
    domain = parsed_url.netloc
    domain_length = len(domain)

    # Extract path length path 길이 추출
    path = parsed_url.path
    path_length = len(path)

    # Extract parameter length parameter 길이 추출
    query = parsed_url.query
    parameters = parse_qs(query)
    parameter_length = sum(len(v) for v in parameters.values())

    # Extract TLD (Top-Level Domain) length TLD 길이 추출
    tld = parsed_url.netloc.split('.')[-1]
    tld_length = len(tld)

    return domain_length, path_length, parameter_length, tld_length

# %%
url_http_copy = url_http.copy()
url_http_copy[['domain_length', 'path_length', 'parameter_length', 'tld_length']] = url_http_copy['url'].apply(lambda x: pd.Series(extract_url_info(x)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 2
#       1 url_http_copy = url_http.copy()
# ----> 2 url_http_copy[['domain_length', 'path_length', 'parameter_length', 'tld_length']] = url_http_copy['url'].apply(lambda x: pd.Series(extract_url_info(x)))
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'url'

# %%
url_http_copy
# Out:
#          Unnamed: 0                                                url  type  \
# 2                 5  http://buzzfil.net/m/show-art/ils-etaient-loin...  good
# 17               27  http://hollywoodlife.com/2014/05/01/rihanna-ih...  good
# 33               49  http://interpark.com/displaycorner/FreeMarket....  good
# 63               91  http://fanpage.gr/family/gineka/%ce%b1%cf%85%c...  good
# 66               95  http://worldoftanks.ru/ru/content/guide/paymen...  good
# ...             ...                                                ...   ...
# 1292504      639814         httpd.apache.org/docs/mod/mod_rewrite.html   bad
# 1292544      639854             www.minihttpserver.net/htmlg/index.php   bad
# 1294181      641491       nwclug.harper.cc.il.us/httpd/html/index.html   bad
# 1295941      643251              www.minihttpserver.net/home/index.php   bad
# 1298177      645487                 lipas.uwasa.fi/~ts/http/tsfaq.html   bad
#
#          domain_length  path_length  parameter_length  tld_length
# 2                   11          100                 0           3
# 17                  17           61                 0           3
# 33                  13           28                 5           3
# 63                  10          212                 0           2
# 66                  15           76                 0           2
# ...                ...          ...               ...         ...
# 1292504             16           26                 0           3
# 1292544             22           16                 0           3
# 1294181             22           22                 0           2
# 1295941             22           15                 0           3
# 1298177             14           20                 0           2
#
# [296727 rows x 7 columns]

# %%
bad_data = url_http_copy[url_http_copy['type'] == 'bad']
mean_values = bad_data[['domain_length', 'path_length', 'parameter_length', 'tld_length']].mean()
mean_values
# Out:
# domain_length       18.612892
# path_length         19.079652
# parameter_length     0.957355
# tld_length           4.546927
# dtype: float64

# %%
good_data = url_http_copy[url_http_copy['type'] == 'good']
mean_values = good_data[['domain_length', 'path_length', 'parameter_length', 'tld_length']].mean()
mean_values
# Out:
# domain_length       12.310836
# path_length         72.731812
# parameter_length     0.672574
# tld_length           2.714791
# dtype: float64

# %%
print(url_http_copy[url_http_copy['type'] == 'good']['domain_length'].value_counts().head(30))
print(url_http_copy[url_http_copy['type'] == 'bad']['domain_length'].value_counts().head(30))
# Out:
# 15     5251
# 10     4625
# 13     4232
# 12     3961
# 11     3853
# 9      3248
# 14     3034
# 6      2089
# 17     1764
# 7      1688
# 8      1210
# 16      638
# 18      365
# 20      255
# 21      225
# 19      184
# 23       56
# 22       43
# 24       43
# 26       36
# 25       31
# 133      24
# 30       18
# 29       15
# 31       12
# 127      12
# 111      10
# 28       10
# 96       10
# 35       10
# Name: domain_length, dtype: int64
# 20    38193
# 19    33659
# 21    24895
# 18    22883
# 13    15871
# 17    14860
# 14    14616
# 15    13126
# 12    11106
# 16    10959
# 9      7107
# 23     5687
# 11     5555
# 22     5401
# 24     5124
# 25     4150
# 10     3902
# 26     3550
# 28     2732
# 27     2392
# 29     2157
# 30     1492
# 31     1447
# 32     1009
# 34      905
# 6       866
# 33      757
# 8       736
# 7       598
# 35      489
# Name: domain_length, dtype: int64

# %%
print(url_http_copy[url_http_copy['type'] == 'good']['path_length'].value_counts().head(30))
print(url_http_copy[url_http_copy['type'] == 'bad']['path_length'].value_counts().head(30))
# Out:
# 65    1463
# 57    1444
# 73     897
# 66     827
# 69     823
# 71     821
# 67     818
# 70     779
# 74     779
# 75     773
# 77     773
# 72     749
# 68     747
# 15     725
# 5      720
# 78     697
# 76     691
# 79     670
# 81     654
# 10     632
# 80     611
# 64     583
# 85     571
# 82     545
# 83     542
# 84     524
# 87     496
# 93     449
# 86     447
# 4      436
# Name: path_length, dtype: int64
# 7     65599
# 10    42683
# 2     17485
# 11     7114
# 3      6182
# 20     4951
# 13     4929
# 9      4690
# 14     3877
# 15     3795
# 8      3482
# 12     3473
# 17     3414
# 16     3342
# 18     3037
# 28     2896
# 24     2851
# 21     2828
# 23     2707
# 22     2545
# 19     2279
# 4      2168
# 1      2078
# 48     2034
# 5      1940
# 27     1910
# 25     1887
# 26     1738
# 38     1635
# 34     1609
# Name: path_length, dtype: int64

# %%
print(url_http_copy[url_http_copy['type'] == 'good']['parameter_length'].value_counts().head(30))
print(url_http_copy[url_http_copy['type'] == 'bad']['parameter_length'].value_counts().head(30))
# Out:
# 0     26235
# 1      5110
# 2      2335
# 4      1331
# 3       854
# 5       613
# 6       373
# 8       100
# 7        40
# 12       34
# 9        25
# 10       11
# 11        8
# 14        1
# 39        1
# Name: parameter_length, dtype: int64
# 0     192315
# 4      17155
# 5      11527
# 1      11039
# 2       9689
# 3       8428
# 6       5158
# 8       1914
# 7       1585
# 9        334
# 10       307
# 19        93
# 11        68
# 13        13
# 14        11
# 12         8
# 21         6
# 17         3
# 16         1
# 51         1
# 18         1
# Name: parameter_length, dtype: int64

# %%
print(url_http_copy[url_http_copy['type'] == 'good']['tld_length'].value_counts().head(30))
print(url_http_copy[url_http_copy['type'] == 'bad']['tld_length'].value_counts().head(30))
# Out:
# 3    26224
# 2    10710
# 4      137
# Name: tld_length, dtype: int64
# 3     84459
# 2     81106
# 9     51344
# 8     31087
# 4      5815
# 7      3842
# 1      1539
# 5       262
# 6       189
# 10        6
# 12        4
# 0         2
# 11        1
# Name: tld_length, dtype: int64

# %% [markdown]
# 1번특징 생성, 갱신일자 확인, 만료일자 서비스 기간 짧음

# %%
#도메인 유효 기간을 계산하는 함수
#일부 변형해서 갱신일자 가져올 수 있을 것 같음
import whois, sys
import urllib.parse
from datetime import datetime
  
# domain 유효 기간 계산
def get_total_date(url) :
    domain = whois.whois(url) #도메인 추출
    if type(domain.expiration_date) is list : #도메인에서 만료일 추출, 리스트 형태면 첫번째 값 가져옴
        expiration_date = domain.expiration_date[0]
    else :
        expiration_date = domain.expiration_date
        
    if type(domain.updated_date) is list : #도메인에서 갱신일 추출, 리스트 형태면 첫번째 값 가져옴
        updated_date = domain.updated_date[0]
    else :
        updated_date = domain.updated_date
    if updated_date is None:#결과 없을 시 none 리턴
        return None
    if expiration_date is None:
        return None
    
    #도메인 유효 기간 계산(만료일-갱신일)
    total_date = (expiration_date - updated_date).days 
    
    return total_date

# %%
#위에 정의한 함수 사용해서 도메인 유효기간 배열 생성

domainDate = []
dataset = output

for i, item in dataset.iterrows():
    try:
        date = get_total_date(item['url'])
        if date is None: #함수 결과값이 없을 경우
            domainDate.append(np.nan) #Nan 넣어둠
        else:
            domainDate.append(date)
    except: #양식이 없는 양식일 경우(함수에러가 뜸)
        domainDate.append(np.nan)
        continue

dataset['domainDate'] = domainDate
dataset
# domainDate = pd.DataFrame(domainDate, columns=['domainDate'])

# #원활한 저장 위해 인덱스 초기화
# dataset = dataset.reset_index()
# domainDate = domainDate.reset_index()

# #데이터프레임 병합(index가 여러개 생기는 것 같은데 해결해야할수도)
# dataset = pd.concat([dataset, domainDate], axis=1)
# Out:
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 111] Connection refused
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 113] No route to host
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 113] No route to host
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 111] Connection refused
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 104] Connection reset by peer
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 104] Connection reset by peer
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 113] No route to host
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 111] Connection refused
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - timed out
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno -2] Name or service not known
# Error trying to connect to socket: closing socket - [Errno 104] Connection reset by peer

# %% [markdown]
# **6번특징**

# %% [markdown]
# url 길이는 특징으로 사용 불가

# %%
#정상 데이터 url 길이 측정
#count = url 길이가 20개 이하인 갯수
#midLen/len(data) = url 길이의 평균
midLen = 0;
count = 0
for index, row in data.iterrows():
    midLen += len(row['url'])
    if len(row['url']) < 20:
        count += 1

print(count)
print(len(data))
print(midLen)
print(midLen/len(data))
# Out:
# 52358
# 821027
# 42674178
# 51.976582986917606

# %%
#악성 데이터 url 길이 측정
#count = url 길이가 20개 이하인 갯수
#midLen/len(data) = url 길이의 평균
testMidLen = 0;
testCount = 0;
for index, row in test_data.iterrows():
    testMidLen += len(row['url'])
    if len(row['url']) < 20:
        testCount += 1
        
    
print(testCount)
print(len(test_data))
print(testMidLen)
print(testMidLen/len(test_data))
# Out:
# 27922
# 482854
# 27953573
# 57.89239190314257

# %%
#정상데이터 url 길이 삽입(lenUrl 열)
new_lenUrl = []
for index, row in data.iterrows():
    new_lenUrl.append(len(row['url']))
    
data['lenUrl'] = new_lenUrl
data
# Out:
#                                                       url  type  lenUrl
# 1                     mp3raid.com/music/krizz_kaliko.html  good      35
# 2                         bopsecrets.org/rexroth/cr/1.htm  good      31
# 5       http://buzzfil.net/m/show-art/ils-etaient-loin...  good     118
# 6           espn.go.com/nba/player/_/id/3457/brandon-rush  good      45
# 7          yourbittorrent.com/?q=anthony-hamilton-soulife  good      46
# ...                                                   ...   ...     ...
# 483590  youthleaguesusa.com/potomacsoccer/2011/Tournam...  good      54
# 483591                                     zip-codes.com/  good      14
# 483592                    owens.edu/news-releases/?p=2052  good      31
# 483593      1.safesecureweb.com/egale/index.asp?item=1173  good      45
# 483594               yurika.otakuthon.com/reg/main.pl/en/  good      36
#
# [821027 rows x 3 columns]

# %%
#악성데이터 url 길이 삽입(lenUrl 열)
test_new_lenUrl = []
for index, row in test_data.iterrows():
    test_new_lenUrl.append(len(row['url']))
    
test_data['lenUrl'] = test_new_lenUrl
test_data
# Out:
#                                                       url type  lenUrl
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...  bad     225
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...  bad      81
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....  bad     177
# 3       mail.printakid.com/www.online.americanexpress....  bad      60
# 4       thewhiskeydregs.com/wp-content/themes/widescre...  bad     116
# ...                                                   ...  ...     ...
# 651186            xbox360.ign.com/objects/850/850402.html  bad      39
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/  bad      44
# 651188         www.gamespot.com/xbox360/action/deadspace/  bad      42
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)  bad      45
# 651190          www.angelfire.com/goth/devilmaycrytonite/  bad      41
#
# [482854 rows x 3 columns]

# %% [markdown]
# ip주소 : 포트가 url에 있으면 악성

# %%
from urllib.parse import urlparse
import re
#정상데이터

new_match = []
for index, row in data.iterrows():
    url = row['url']
    parsed_url = urlparse(url)
    host = parsed_url.netloc
    ##
    #host가져와서 xxx.xxx.xxx:포트번호 찾기
    ##
    if re.match(r'^\d+\.\d+\.\d+\.\d+:\d+$', host) :
        new_match.append(True)
    else :
        new_match.append(False)

#매칭되면 열 추가
data['IPT/F'] = new_match
data
# Out:
#                                                       url  type  lenUrl  IPT/F
# 1                     mp3raid.com/music/krizz_kaliko.html  good      35  False
# 2                         bopsecrets.org/rexroth/cr/1.htm  good      31  False
# 5       http://buzzfil.net/m/show-art/ils-etaient-loin...  good     118  False
# 6           espn.go.com/nba/player/_/id/3457/brandon-rush  good      45  False
# 7          yourbittorrent.com/?q=anthony-hamilton-soulife  good      46  False
# ...                                                   ...   ...     ...    ...
# 483590  youthleaguesusa.com/potomacsoccer/2011/Tournam...  good      54  False
# 483591                                     zip-codes.com/  good      14  False
# 483592                    owens.edu/news-releases/?p=2052  good      31  False
# 483593      1.safesecureweb.com/egale/index.asp?item=1173  good      45  False
# 483594               yurika.otakuthon.com/reg/main.pl/en/  good      36  False
#
# [821027 rows x 4 columns]

# %%
from urllib.parse import urlparse
import re
#악성데이터

new_match_col = []
for index, row in test_data.iterrows():
    url = row['url']
    parsed_url = urlparse(url)
    host = parsed_url.netloc
    ##
    #host가져와서 xxx.xxx.xxx:포트번호 찾기
    ##
    if re.match(r'^\d+\.\d+\.\d+\.\d+:\d+$', host) :
        new_match_col.append(True)
    else :
        new_match_col.append(False)

#매칭되면 열 추가
test_data['IPT/F'] = new_match_col
test_data
# Out:
#                                                       url type  lenUrl  IPT/F
# 0       nobell.it/70ffb52d079109dca5664cce6f317373782/...  bad     225  False
# 1       www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...  bad      81  False
# 2       serviciosbys.com/paypal.cgi.bin.get-into.herf....  bad     177  False
# 3       mail.printakid.com/www.online.americanexpress....  bad      60  False
# 4       thewhiskeydregs.com/wp-content/themes/widescre...  bad     116  False
# ...                                                   ...  ...     ...    ...
# 651186            xbox360.ign.com/objects/850/850402.html  bad      39  False
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/  bad      44  False
# 651188         www.gamespot.com/xbox360/action/deadspace/  bad      42  False
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)  bad      45  False
# 651190          www.angelfire.com/goth/devilmaycrytonite/  bad      41  False
#
# [482854 rows x 4 columns]

# %%
data['lenUrl'].value_counts().head(30)
# Out:
# 31    32693
# 33    17172
# 27    17030
# 35    16432
# 36    16302
# 37    15973
# 34    15967
# 30    15928
# 38    15917
# 42    15415
# 32    15316
# 24    15216
# 29    15158
# 39    15133
# 41    14846
# 40    14765
# 26    14264
# 28    14224
# 44    14180
# 43    14152
# 25    14116
# 45    13999
# 46    13370
# 23    12385
# 47    12302
# 48    12301
# 49    11829
# 50    11573
# 22    11377
# 51    10902
# Name: lenUrl, dtype: int64

# %%
test_data['lenUrl'].value_counts().head(30)
# Out:
# 33    27151
# 34    27088
# 35    19249
# 32    17170
# 29    14377
# 28    12681
# 27    12237
# 30    12151
# 31    10763
# 26     8510
# 40     7447
# 25     6958
# 36     6493
# 37     6372
# 24     6188
# 38     6057
# 39     5898
# 41     5844
# 23     5802
# 22     5587
# 21     5537
# 44     5410
# 42     5235
# 43     5082
# 19     4835
# 20     4798
# 45     4686
# 46     4550
# 18     4325
# 47     4218
# Name: lenUrl, dtype: int64

# %% [markdown]
# **2번특징**

# %%
#url에서 domain 추출

import csv
from urllib.parse import urlparse

input_file = 'unique_url.csv'
output_file = 'domain.csv'

output_header = ['URL', 'Domain']

# 도메인 추출 함수 정의
def extract_domain(url):
    try:
        parsed_url = urlparse(url)
        domain = parsed_url.netloc
        return domain
    except Exception as e:
        print(f"Error: {e}")
        return None

with open(input_file, 'r') as file:
    
    reader = csv.reader(file)

    domains = []

    # 행 단위로 데이터 처리
    for row in reader:

        url = row[0]

        # 도메인 추출
        domain = extract_domain(url)

        domains.append((url, domain))

with open(output_file, 'w', newline='') as output:
    writer = csv.writer(output)

    # 헤더 쓰기
    writer.writerow(output_header)

    writer.writerows(domains)

# %%
#domain에서 ip 추출

import csv
import dns.resolver

def ip_from_domain(domain):
    try:
        r = dns.resolver.Resolver()
        r.nameserver = ['8.8.8.8']
        ip = dns.resolver.resolve(domain, 'A')
        if ip:
            return str(ip[0])
    except Exception as e:
        print(f"Error: {e}")
        return None

csv_file = "domain.csv"

output_csv_file = "ip.csv"

parsed_ip = []

with open(csv_file, "r", encoding='utf-8') as file:
    reader = csv.DictReader(file)

    with open(output_csv_file, "w", newline="", encoding='utf-8') as output_file:
        writer = csv.writer(output_file)
        writer.writerow(["ip"])
        
        for row in reader:
            domain = row['domain']
            ip = ip_from_domain(domain)
            parsed_ip.append(ip)
            writer.writerow([ip])

# %%
#ip에서 netname, asn 추출

from ipwhois import IPWhois
import pandas as pd
import csv
from concurrent.futures import ProcessPoolExecutor
import os

def get_ip_information(ip):
    try:
        ip_info = {}
        w = IPWhois(ip)
        result = w.lookup_rdap()

        ip_info['IP'] = ip
        ip_info['NetName'] = result.get('asn_description', '') #netname 추출
        ip_info['ASN'] = result.get('asn', '') #asn 추출
        return ip_info
    except Exception as e:
        print(f"Error: {e}")
        return None

ip_dataset_file = "ip.csv"
output_csv_file = "ip_info.csv"

df = pd.read_csv(ip_dataset_file)

df['IP'] = df['IP'].astype(str)

# 중복된 IP 주소 제거
unique_ips = df['IP'].unique()

max_workers = os.cpu_count() 

# 멀티프로세싱으로 IP 정보 추출
ip_information = []
try:
    with ProcessPoolExecutor(max_workers=max_workers) as executor:
        results = executor.map(get_ip_information, unique_ips)
        for result in results:
            if result is not None:
                ip_information.append(result)
except Exception as e:
    print(f"Error: {e}")

with open(output_csv_file, "w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=['IP', 'NetName', 'ASN'])
    writer.writeheader()
    writer.writerows(ip_information)

# %%
#추출된 netname과 asn에서 netname만 따로 저장

import csv

input_file = 'ip_info.csv'
output_file = 'netname.csv'

with open(input_file, 'r') as file:
    reader = csv.reader(file)
    
    # 첫 번째 열 데이터를 저장할 리스트 생성
    first_column_data = []
    
    # 행 단위로 데이터 처리
    for row in reader:
        # 첫 번째 열 데이터를 리스트에 추가
        first_column_data.append(row[0])
        
with open(output_file, 'w', newline='') as output:
    writer = csv.writer(output)
    
    for data in first_column_data:
        writer.writerow([data])

# %%
#추출된 netname과 asn에서 asn만 따로 저장

import csv

input_file = 'ip_info.csv'
output_file = 'asn.csv'

with open(input_file, 'r') as file:
    reader = csv.reader(file)
    
    # 두 번째 열 데이터를 저장할 리스트 생성
    second_column_data = []
    
    # 행 단위로 데이터 처리
    for row in reader:
        # 두 번째 열 데이터를 리스트에 추가
        second_column_data.append(row[1])
        
with open(output_file, 'w', newline='') as output:
    writer = csv.writer(output)
    
    for data in second_column_data:
        writer.writerow([data])

# %%
#netname에서 중복된 값 제거

import csv

input_file = 'netname.csv'
output_file = 'unique_netname.csv'

# 중복된 값을 저장할 집합(set) 생성
unique_values = set()

with open(input_file, 'r') as file:

    reader = csv.reader(file)
    
    unique_rows = []
    
    # 행 단위로 데이터 처리
    for row in reader:
        # 행에 공백이 있는 경우 무시
        if not any(row):
            continue
        
        # 현재 행의 값을 문자열로 변환하여 중복 여부 확인
        row_string = ','.join(row)
        
        # 중복된 값이 이미 존재하는 경우 해당 행을 건너뛰고 다음 행으로 진행
        if row_string in unique_values:
            continue
        
        # 중복된 값이 존재하지 않는 경우 집합과 리스트에 행 추가
        unique_values.add(row_string)
        unique_rows.append(row)
        
with open(output_file, 'w', newline='') as output:
    writer = csv.writer(output)
    writer.writerows(unique_rows)

# %%
#asn에서 중복된 값 제거

import csv

input_file = 'asn.csv'
output_file = 'unique_asn.csv'

# 중복된 값을 저장할 집합(set) 생성
unique_values = set()

with open(input_file, 'r') as file:

    reader = csv.reader(file)
    
    unique_rows = []
    
    # 행 단위로 데이터 처리
    for row in reader:
        # 행에 공백이 있는 경우 무시
        if not any(row):
            continue
        
        # 현재 행의 값을 문자열로 변환하여 중복 여부 확인
        row_string = ','.join(row)
        
        # 중복된 값이 이미 존재하는 경우 해당 행을 건너뛰고 다음 행으로 진행
        if row_string in unique_values:
            continue
        
        # 중복된 값이 존재하지 않는 경우 집합과 리스트에 행 추가
        unique_values.add(row_string)
        unique_rows.append(row)
        
with open(output_file, 'w', newline='') as output:
    writer = csv.writer(output)
    writer.writerows(unique_rows)

# %%
asn = pd.read_csv("./unique_asn.csv")
asn
# Out:
#          ASN
# 0      14061
# 1      63949
# 2     133618
# 3      58182
# 4      15169
# ...      ...
# 2638  202448
# 2639  400331
# 2640   39383
# 2641   62068
# 2642   64111
#
# [2643 rows x 1 columns]

# %%
netname = pd.read_csv("./unique_netname.csv")
netname
# Out:
#                                           NetName
# 0                            DIGITALOCEAN-ASN, US
# 1     AKAMAI-LINODE-AP Akamai Connected Cloud, SG
# 2        TRELLIAN-AS-AP Trellian Pty. Limited, AU
# 3                                     WIX_COM, IL
# 4                                      GOOGLE, US
# ...                                           ...
# 2584                        MVPS www.mvps.net, CY
# 2585                        SITEACTION-TOR-01, CA
# 2586                            TELESYSTEM-AS, RO
# 2587                 SPECTRAIP SpectraIP B.V., NL
# 2588         INFORMATICA BLUEHOSTING LIMITADA, CL
#
# [2589 rows x 1 columns]

# %%
output = pd.concat([data, test_data])
output = output.drop_duplicates(subset=['url'])
output.type.value_counts()
# Out:
# good    476177
# bad     334674
# Name: type, dtype: int64

# %%
model_data = pd.merge(dataset, output, on='url', how='inner')
model_data = model_data.drop_duplicates(subset=['url'])
model_data = model_data.drop('type_y', axis=1)
model_data
# Out:
#                                                        url type_x  specChar  \
# 0                      mp3raid.com/music/krizz_kaliko.html   good         1
# 2                          bopsecrets.org/rexroth/cr/1.htm   good         0
# 4        http://buzzfil.net/m/show-art/ils-etaient-loin...   good        16
# 5            espn.go.com/nba/player/_/id/3457/brandon-rush   good         2
# 7           yourbittorrent.com/?q=anthony-hamilton-soulife   good         4
# ...                                                    ...    ...       ...
# 1303876                 http://211.137.225.95:47475/Mozi.m    bad         0
# 1303877                 http://115.55.246.246:44661/Mozi.m    bad         0
# 1303878                http://219.155.142.211:55621/Mozi.m    bad         0
# 1303879                   http://42.238.164.8:48848/Mozi.m    bad         0
# 1303880                   http://172.36.45.82:41684/Mozi.m    bad         0
#
#          lenUrl  IPT/F
# 0            35  False
# 2            31  False
# 4           118  False
# 5            45  False
# 7            46  False
# ...         ...    ...
# 1303876      34   True
# 1303877      34   True
# 1303878      35   True
# 1303879      32   True
# 1303880      32   True
#
# [810851 rows x 5 columns]

# %%
model_data = pd.merge(dataset, url_http_copy, on='url', how='left')
model_data = model_data.drop_duplicates(subset=['url'])
model_data = model_data.drop('Unnamed: 0', axis=1)
model_data = model_data.drop('type', axis=1)
model_data
# Out:
#                                                       url type_x  specChar  \
# 0                     mp3raid.com/music/krizz_kaliko.html   good         1
# 1                         bopsecrets.org/rexroth/cr/1.htm   good         0
# 2       http://buzzfil.net/m/show-art/ils-etaient-loin...   good        16
# 3           espn.go.com/nba/player/_/id/3457/brandon-rush   good         2
# 4          yourbittorrent.com/?q=anthony-hamilton-soulife   good         4
# ...                                                   ...    ...       ...
# 822955                 http://211.137.225.95:47475/Mozi.m    bad         0
# 822956                 http://115.55.246.246:44661/Mozi.m    bad         0
# 822957                http://219.155.142.211:55621/Mozi.m    bad         0
# 822958                   http://42.238.164.8:48848/Mozi.m    bad         0
# 822959                   http://172.36.45.82:41684/Mozi.m    bad         0
#
#         lenUrl  IPT/F  domain_length  path_length  parameter_length  \
# 0           35  False            NaN          NaN               NaN
# 1           31  False            NaN          NaN               NaN
# 2          118  False           11.0        100.0               0.0
# 3           45  False            NaN          NaN               NaN
# 4           46  False            NaN          NaN               NaN
# ...        ...    ...            ...          ...               ...
# 822955      34   True           20.0          7.0               0.0
# 822956      34   True           20.0          7.0               0.0
# 822957      35   True           21.0          7.0               0.0
# 822958      32   True           18.0          7.0               0.0
# 822959      32   True           18.0          7.0               0.0
#
#         tld_length
# 0              NaN
# 1              NaN
# 2              3.0
# 3              NaN
# 4              NaN
# ...            ...
# 822955         8.0
# 822956         9.0
# 822957         9.0
# 822958         7.0
# 822959         8.0
#
# [810851 rows x 9 columns]

# %%
model_data.fillna(0, inplace=True)
model_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 810851 entries, 0 to 822959
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   url               810851 non-null  object
#  1   type_x            810851 non-null  object
#  2   specChar          810851 non-null  int64
#  3   lenUrl            810851 non-null  int64
#  4   IPT/F             810851 non-null  bool
#  5   domain_length     810851 non-null  float64
#  6   path_length       810851 non-null  float64
#  7   parameter_length  810851 non-null  float64
#  8   tld_length        810851 non-null  float64
# dtypes: bool(1), float64(4), int64(2), object(2)
# memory usage: 56.5+ MB

# %%
def extract_features(url):

    
    domain_length, path_length, parameter_length ,tld_length  =extract_url_info(url)
    lenUrl = len(url)
    
    #ip 있는지 확인
    parsed_url = urlparse(url)
    host = parsed_url.netloc
    ##
    #host가져와서 xxx.xxx.xxx:포트번호 찾기
    ##
    if re.match(r'^\d+\.\d+\.\d+\.\d+:\d+$', host) :
        IP = True
    else :
        IP = False
    specChar = countSpecChar(url)
#     print(domain_length, path_length, parameter_length, tld_length, lenUrl, IP, specChar)
    
    data = [[specChar, lenUrl, IP, domain_length, path_length, parameter_length, tld_length]]
    # 컬럼 이름 설정
    columns = [ 'specChar', 'lenUrl', 'IPT/F', 'domain_length', 'path_length', 'parameter_length', 'tld_length']

    # 데이터프레임 생성
    df = pd.DataFrame(data, columns=columns)

    # 데이터프레임 출력
    return df

def countSpecChar(url):
    special_chars = ['?', '!', '~', '@', '#', '$', '%', '^', '&', '*', '-', '=', '_', '+', ',']
    cnt = sum(url.count(char) for char in special_chars)
    return cnt

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# 데이터셋 로드
dataset = model_data

# 피처와 레이블 분리
features = dataset[[ 'specChar', 'lenUrl', 'IPT/F', 'domain_length', 'path_length', 'parameter_length', 'tld_length']]
labels = dataset['type_x']  # 악성 여부를 나타내는 레이블

# 학습 데이터와 테스트 데이터 분리
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.2, random_state=42)

# 랜덤 포레스트 모델 생성 및 학습
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(train_features, train_labels)

# 학습된 모델로 예측 수행
predictions = rf_model.predict(test_features)

# 정확도 평가
accuracy = accuracy_score(test_labels, predictions)
print("Accuracy:", accuracy)

test_url = 'https://www.example.com'

# 테스트 URL의 피처 추출
test_features = extract_features(test_url)  # 추출 함수는 별도로 구현해야 합니다.

# 테스트 URL의 예측
prediction = rf_model.predict(test_features)

# 예측 결과 출력
if prediction == 'bad':
    print("URL is dangerous.")
else:
    print("URL is safe.")
# Out:
# Accuracy: 0.8898631691239494
# URL is dangerous.

# %%
test_url = 'mp3raid.com/music/krizz_kaliko.html'

# 테스트 URL의 피처 추출
test_features = extract_features(test_url)
test_features
# Out:
#    specChar  lenUrl  IPT/F  domain_length  path_length  parameter_length  \
# 0         1      35  False             11           24                 0
#
#    tld_length
# 0           3

# %%
test_url = 'mp3raid.com/music/krizz_kaliko.html'
# 테스트 URL의 피처 추출
test_features = extract_features(test_url)  # 추출 함수는 별도로 구현해야 합니다.

# 테스트 URL의 예측
prediction = rf_model.predict(test_features)

# 예측 결과 출력
if prediction == 'bad':
    print("URL is dangerous.")
else:
    print("URL is safe.")
# Out:
# URL is dangerous.
